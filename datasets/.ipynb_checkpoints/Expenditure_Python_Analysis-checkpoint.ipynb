# 17  197.4  202.8  205.8  206.8  215.1  225.9  244.3  247.8  259.8  263.3
# 18   -2.7   -1.1   -0.7   -2.1   -1.7   -3.2    1.0    6.3    4.6    7.0
# 19  556.9  582.2  603.8  611.8  633.5  671.6  701.3  710.3  702.7  691.8
# 20   36.3   47.4   48.3   52.5   54.7   60.4   57.9   58.8   57.1   68.8
# 21  593.2  629.5  652.1  664.3  688.2  732.0  759.2  769.2  759.8  760.6
#
#      2014   2015   2016
# 0    62.5   59.5   59.2
# 1    11.5   11.7   11.3
# 2    10.0   10.6   10.4
# 3    41.0   37.3   37.5
# 4    37.2   37.0   36.6
# 5    30.2   30.1   29.5
# 6    40.9   40.7   47.1
# 7     6.3    5.6    6.5
# 8     4.3    4.5    4.8
# 9     3.7    3.2    2.4
# 10    5.5    5.2    4.5
# 11   21.1   22.2   28.9
# 12   11.4   11.7   11.6
# 13   10.0   10.3   10.1
# 14  132.3  134.8  138.5
# 15   11.7   12.5   10.9
# 16   87.2   86.4   83.2
# 17  259.6  262.8  265.1
# 18    7.4    6.3    7.7
# 19  690.5  692.1  699.5
# 20   62.8   65.5   54.5
# 21  753.3  757.6  753.9

# %%
df = df.set_index('Unnamed: 0').T.rename_axis('Date').reset_index()
df
# Out:
# Unnamed: 0  Date  1. General public services  \
# 0           2001                        51.9
# 1           2002                        47.9
# 2           2003                        46.0
# 3           2004                        49.1
# 4           2005                        53.1
# 5           2006                        55.5
# 6           2007                        56.6
# 7           2008                        58.5
# 8           2009                        61.6
# 9           2010                        55.4
# 10          2011                        67.8
# 11          2012                        67.7
# 12          2013                        62.0
# 13          2014                        62.5
# 14          2015                        59.5
# 15          2016                        59.2
#
# Unnamed: 0  of which: public and common services  \
# 0                                           10.6
# 1                                           12.2
# 2                                           12.7
# 3                                           13.8
# 4                                           15.0
# 5                                           15.4
# 6                                           14.8
# 7                                           14.3
# 8                                           15.5
# 9                                           15.1
# 10                                          13.8
# 11                                          12.2
# 12                                          11.7
# 13                                          11.5
# 14                                          11.7
# 15                                          11.3
#
# Unnamed: 0  of which: international services  \
# 0                                        5.6
# 1                                        5.7
# 2                                        5.8
# 3                                        6.5
# 4                                        6.8
# 5                                        7.5
# 6                                        7.4
# 7                                        7.6
# 8                                        7.1
# 9                                        7.8
# 10                                       8.4
# 11                                       8.2
# 12                                       8.0
# 13                                      10.0
# 14                                      10.6
# 15                                      10.4
#
# Unnamed: 0  of which: public sector debt interest  2. Defence  \
# 0                                            35.7        34.5
# 1                                            30.0        33.7
# 2                                            27.4        35.0
# 3                                            28.8        36.5
# 4                                            31.4        36.8
# 5                                            32.6        37.3
# 6                                            34.4        37.6
# 7                                            36.6        38.4
# 8                                            39.0        40.9
# 9                                            32.5        41.3
# 10                                           45.7        42.3
# 11                                           47.3        41.0
# 12                                           42.3        37.8
# 13                                           41.0        37.2
# 14                                           37.3        37.0
# 15                                           37.5        36.6
#
# Unnamed: 0  3. Public order and safety  4. Economic affairs  \
# 0                                 27.4                 32.0
# 1                                 30.6                 36.7
# 2                                 31.6                 39.8
# 3                                 33.5                 42.0
# 4                                 35.2                 41.5
# 5                                 35.3                 42.5
# 6                                 35.5                 43.8
# 7                                 36.2                 42.7
# 8                                 37.4                 55.2
# 9                                 37.4                 53.3
# 10                                35.6                 43.0
# 11                                34.0                 40.1
# 12                                32.5                 37.9
# 13                                30.2                 40.9
# 14                                30.1                 40.7
# 15                                29.5                 47.1
#
# Unnamed: 0   of which: enterprise and economic development  \
# 0                                                      6.6
# 1                                                      6.8
# 2                                                      7.7
# 3                                                      7.6
# 4                                                      8.0
# 5                                                      7.7
# 6                                                      7.4
# 7                                                      8.1
# 8                                                     18.0
# 9                                                     13.4
# 10                                                     5.3
# 11                                                     5.1
# 12                                                     5.2
# 13                                                     6.3
# 14                                                     5.6
# 15                                                     6.5
#
# Unnamed: 0  of which: science and technology            ...              \
# 0                                        1.9            ...
# 1                                        2.3            ...
# 2                                        2.7            ...
# 3                                        2.9            ...
# 4                                        3.1            ...
# 5                                        3.6            ...
# 6                                        3.4            ...
# 7                                        3.8            ...
# 8                                        3.6            ...
# 9                                        3.9            ...
# 10                                       3.7            ...
# 11                                       3.8            ...
# 12                                       3.5            ...
# 13                                       4.3            ...
# 14                                       4.5            ...
# 15                                       4.8            ...
#
# Unnamed: 0  5. Environment protection  6. Housing and community amenities  \
# 0                                 6.9                                 7.4
# 1                                 7.2                                 8.2
# 2                                 7.8                                 7.0
# 3                                 7.9                                 8.5
# 4                                 8.6                                 9.9
# 5                                10.2                                12.9
# 6                                11.0                                13.4
# 7                                10.9                                14.8
# 8                                10.2                                17.0
# 9                                11.4                                17.9
# 10                               11.7                                14.3
# 11                               11.1                                10.8
# 12                               11.1                                10.3
# 13                               11.4                                10.0
# 14                               11.7                                10.3
# 15                               11.6                                10.1
#
# Unnamed: 0  7. Health  8. Recreation, culture and religion  9. Education  \
# 0                72.8                                 10.5          61.7
# 1                79.3                                 11.4          67.9
# 2                85.9                                 12.1          70.9
# 3                95.0                                 12.3          77.4
# 4               102.4                                 12.4          80.4
# 5               108.1                                 13.0          84.0
# 6               110.6                                 13.3          85.3
# 7               115.3                                 13.6          89.8
# 8               120.7                                 13.8          92.2
# 9               128.0                                 14.5          96.9
# 10              129.0                                 14.0          98.4
# 11              128.6                                 13.2          91.7
# 12              129.2                                 13.2          87.5
# 13              132.3                                 11.7          87.2
# 14              134.8                                 12.5          86.4
# 15              138.5                                 10.9          83.2
#
# Unnamed: 0  10. Social protection  EU transactions  \
# 0                           172.6             -3.5
# 1                           182.2             -6.4
# 2                           188.5             -2.5
# 3                           197.4             -2.7
# 4                           202.8             -1.1
# 5                           205.8             -0.7
# 6                           206.8             -2.1
# 7                           215.1             -1.7
# 8                           225.9             -3.2
# 9                           244.3              1.0
# 10                          247.8              6.3
# 11                          259.8              4.6
# 12                          263.3              7.0
# 13                          259.6              7.4
# 14                          262.8              6.3
# 15                          265.1              7.7
#
# Unnamed: 0  Public sector expenditure on services  Accounting adjustments  \
# 0                                           474.1                    29.1
# 1                                           498.8                    31.0
# 2                                           522.1                    37.7
# 3                                           556.9                    36.3
# 4                                           582.2                    47.4
# 5                                           603.8                    48.3
# 6                                           611.8                    52.5
# 7                                           633.5                    54.7
# 8                                           671.6                    60.4
# 9                                           701.3                    57.9
# 10                                          710.3                    58.8
# 11                                          702.7                    57.1
# 12                                          691.8                    68.8
# 13                                          690.5                    62.8
# 14                                          692.1                    65.5
# 15                                          699.5                    54.5
#
# Unnamed: 0  Total Managed Expenditure
# 0                               503.2
# 1                               529.9
# 2                               559.8
# 3                               593.2
# 4                               629.5
# 5                               652.1
# 6                               664.3
# 7                               688.2
# 8                               732.0
# 9                               759.2
# 10                              769.2
# 11                              759.8
# 12                              760.6
# 13                              753.3
# 14                              757.6
# 15                              753.9
#
# [16 rows x 23 columns]

# %%
total_exp = DataFrame(df, columns = ["Total Managed Expenditure"])
total_exp
# Out:
# -----------------------------------------------------------------
# TypeError                       Traceback (most recent call last)
# <ipython-input-86-02eeab2a39e0> in <module>()
# ----> 1 total_exp = DataFrame(df, columns = "Total Managed Expenditure")
#       2 total_exp
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     262         if isinstance(data, BlockManager):
#     263             mgr = self._init_mgr(data, axes=dict(index=index, columns=columns),
# --> 264                                  dtype=dtype, copy=copy)
#     265         elif isinstance(data, dict):
#     266             mgr = self._init_dict(data, index, columns, dtype=dtype)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/generic.py in _init_mgr(self, mgr, axes, dtype, copy)
#     148                 mgr = mgr.reindex_axis(axe,
#     149                                        axis=self._get_block_manager_axis(a),
# --> 150                                        copy=False)
#     151
#     152         # make a copy if explicitly requested
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/core/internals.py in reindex_axis(self, new_index, axis, method, limit, fill_value, copy)
#    3804         Conform block manager to new index.
#    3805         """
# -> 3806         new_index = _ensure_index(new_index)
#    3807         new_index, indexer = self.axes[axis].reindex(new_index, method=method,
#    3808                                                      limit=limit)
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/indexes/base.py in _ensure_index(index_like, copy)
#    3663             index_like = copy(index_like)
#    3664
# -> 3665     return Index(index_like)
#    3666
#    3667
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     291                          **kwargs)
#     292         elif data is None or is_scalar(data):
# --> 293             cls._scalar_data_error(data)
#     294         else:
#     295             if (tupleize_cols and isinstance(data, list) and data and
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/pandas/indexes/base.py in _scalar_data_error(cls, data)
#     581         raise TypeError('{0}(...) must be called with a collection of some '
#     582                         'kind, {1} was passed'.format(cls.__name__,
# --> 583                                                       repr(data)))
#     584
#     585     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, 'Total Managed Expenditure' was passed
